# %%
from pyspark.conf import SparkConf
from pyspark.context import SparkContext
from pyspark.sql import SparkSession
from pyspark.ml.clustering import KMeans
from pyspark.ml.linalg import Vectors
import random

# %%
def RandLoc(l, N):
    for _ in range(N):
        l.append((Vectors.dense([random.random(), random.random()]), 1))
    return l

# %%
def SKMeans(l, K):
    conf = SparkConf().setAppName("KMeans").setMaster("local")
    sc = SparkContext(conf=conf)
    kmeans = KMeans().setK(K).setSeed(1)
    model = kmeans.fit(SparkSession(sc).createDataFrame(l, ["features", "weightCol"]))
    centers = model.clusterCenters()
    for center in centers:
        print(center)

# %%
l = []
RandLoc(l, 200000)
# Out:
# [(DenseVector([0.4481, 0.6061]), 1),
#  (DenseVector([0.3769, 0.6519]), 1),
#  (DenseVector([0.8599, 0.1567]), 1),
#  (DenseVector([0.9289, 0.2719]), 1),
#  (DenseVector([0.3313, 0.7767]), 1),
#  (DenseVector([0.7462, 0.7743]), 1),
#  (DenseVector([0.9534, 0.9036]), 1),
#  (DenseVector([0.2083, 0.5445]), 1),
#  (DenseVector([0.2686, 0.2596]), 1),
#  (DenseVector([0.7354, 0.9334]), 1),
#  (DenseVector([0.2556, 0.0534]), 1),
#  (DenseVector([0.8023, 0.0391]), 1),
#  (DenseVector([0.7009, 0.7068]), 1),
#  (DenseVector([0.2075, 0.9423]), 1),
#  (DenseVector([0.1217, 0.3233]), 1),
#  (DenseVector([0.9067, 0.2188]), 1),
#  (DenseVector([0.865, 0.57]), 1),
#  (DenseVector([0.759, 0.0781]), 1),
#  (DenseVector([0.0542, 0.1259]), 1),
#  (DenseVector([0.6787, 0.9251]), 1),
#  (DenseVector([0.4361, 0.9101]), 1),
#  (DenseVector([0.6621, 0.1912]), 1),
#  (DenseVector([0.7303, 0.4728]), 1),
#  (DenseVector([0.6981, 0.6788]), 1),
#  (DenseVector([0.413, 0.0279]), 1),
#  (DenseVector([0.4832, 0.1337]), 1),
#  (DenseVector([0.0234, 0.5982]), 1),
#  (DenseVector([0.6209, 0.651]), 1),
#  (DenseVector([0.3156, 0.3023]), 1),
#  (DenseVector([0.6744, 0.9111]), 1),
#  (DenseVector([0.359, 0.7772]), 1),
#  (DenseVector([0.5636, 0.8228]), 1),
#  (DenseVector([0.2172, 0.2856]), 1),
#  (DenseVector([0.4181, 0.7041]), 1),
#  (DenseVector([0.8275, 0.722]), 1),
#  (DenseVector([0.2158, 0.9855]), 1),
#  (DenseVector([0.2504, 0.156]), 1),
#  (DenseVector([0.0225, 0.3141]), 1),
#  (DenseVector([0.6547, 0.4236]), 1),
#  (DenseVector([0.8787, 0.5465]), 1),
#  (DenseVector([0.2749, 0.1419]), 1),
#  (DenseVector([0.6418, 0.4654]), 1),
#  (DenseVector([0.2766, 0.5289]), 1),
#  (DenseVector([0.2249, 0.1396]), 1),
#  (DenseVector([0.144, 0.3772]), 1),
#  (DenseVector([0.1463, 0.581]), 1),
#  (DenseVector([0.8819, 0.7296]), 1),
#  (DenseVector([0.1657, 0.8167]), 1),
#  (DenseVector([0.3668, 0.2631]), 1),
#  (DenseVector([0.886, 0.7439]), 1),
#  (DenseVector([0.6812, 0.9117]), 1),
#  (DenseVector([0.5965, 0.5218]), 1),
#  (DenseVector([0.8366, 0.3837]), 1),
#  (DenseVector([0.3138, 0.481]), 1),
#  (DenseVector([0.6201, 0.3732]), 1),
#  (DenseVector([0.2574, 0.5114]), 1),
#  (DenseVector([0.9837, 0.3527]), 1),
#  (DenseVector([0.3029, 0.9467]), 1),
#  (DenseVector([0.652, 0.7429]), 1),
#  (DenseVector([0.4451, 0.4983]), 1),
#  (DenseVector([0.5116, 0.4536]), 1),
#  (DenseVector([0.4892, 0.3851]), 1),
#  (DenseVector([0.0838, 0.3648]), 1),
#  (DenseVector([0.1506, 0.0437]), 1),
#  (DenseVector([0.8221, 0.9822]), 1),
#  (DenseVector([0.5839, 0.9993]), 1),
#  (DenseVector([0.3478, 0.2231]), 1),
#  (DenseVector([0.8005, 0.3368]), 1),
#  (DenseVector([0.4626, 0.621]), 1),
#  (DenseVector([0.9869, 0.8728]), 1),
#  (DenseVector([0.3545, 0.1333]), 1),
#  (DenseVector([0.6658, 0.4811]), 1),
#  (DenseVector([0.7248, 0.4466]), 1),
#  (DenseVector([0.79, 0.0137]), 1),
#  (DenseVector([0.2382, 0.8192]), 1),
#  (DenseVector([0.4368, 0.2852]), 1),
#  (DenseVector([0.9579, 0.3833]), 1),
#  (DenseVector([0.9864, 0.9343]), 1),
#  (DenseVector([0.5277, 0.1161]), 1),
#  (DenseVector([0.2001, 0.8224]), 1),
#  (DenseVector([0.8222, 0.6927]), 1),
#  (DenseVector([0.4633, 0.3879]), 1),
#  (DenseVector([0.9758, 0.0329]), 1),
#  (DenseVector([0.3986, 0.0525]), 1),
#  (DenseVector([0.9299, 0.9685]), 1),
#  (DenseVector([0.3323, 0.9767]), 1),
#  (DenseVector([0.4561, 0.6785]), 1),
#  (DenseVector([0.6232, 0.0138]), 1),
#  (DenseVector([0.662, 0.9725]), 1),
#  (DenseVector([0.3466, 0.438]), 1),
#  (DenseVector([0.1925, 0.6986]), 1),
#  (DenseVector([0.3494, 0.6696]), 1),
#  (DenseVector([0.4641, 0.5077]), 1),
#  (DenseVector([0.9596, 0.8801]), 1),
#  (DenseVector([0.263, 0.2474]), 1),
#  (DenseVector([0.7624, 0.8184]), 1),
#  (DenseVector([0.5786, 0.1328]), 1),
#  (DenseVector([0.5536, 0.9333]), 1),
#  (DenseVector([0.6913, 0.6736]), 1),
#  (DenseVector([0.8463, 0.0596]), 1),
#  (DenseVector([0.5146, 0.6812]), 1),
#  (DenseVector([0.0665, 0.7206]), 1),
#  (DenseVector([0.9742, 0.2735]), 1),
#  (DenseVector([0.9015, 0.1211]), 1),
#  (DenseVector([0.3743, 0.5309]), 1),
#  (DenseVector([0.9579, 0.6958]), 1),
#  (DenseVector([0.3775, 0.0233]), 1),
#  (DenseVector([0.1616, 0.6043]), 1),
#  (DenseVector([0.6101, 0.479]), 1),
#  (DenseVector([0.9611, 0.4508]), 1),
#  (DenseVector([0.9428, 0.3427]), 1),
#  (DenseVector([0.2567, 0.8366]), 1),
#  (DenseVector([0.4006, 0.4409]), 1),
#  (DenseVector([0.1696, 0.6831]), 1),
#  (DenseVector([0.5931, 0.3382]), 1),
#  (DenseVector([0.2611, 0.1142]), 1),
#  (DenseVector([0.1339, 0.3685]), 1),
#  (DenseVector([0.3347, 0.4421]), 1),
#  (DenseVector([0.7905, 0.1399]), 1),
#  (DenseVector([0.6883, 0.8207]), 1),
#  (DenseVector([0.5803, 0.3348]), 1),
#  (DenseVector([0.8191, 0.9543]), 1),
#  (DenseVector([0.0725, 0.6599]), 1),
#  (DenseVector([0.7112, 0.9156]), 1),
#  (DenseVector([0.9621, 0.686]), 1),
#  (DenseVector([0.8846, 0.8117]), 1),
#  (DenseVector([0.0793, 0.4878]), 1),
#  (DenseVector([0.4635, 0.6505]), 1),
#  (DenseVector([0.6892, 0.3572]), 1),
#  (DenseVector([0.7438, 0.9096]), 1),
#  (DenseVector([0.2364, 0.0217]), 1),
#  (DenseVector([0.9746, 0.6856]), 1),
#  (DenseVector([0.4954, 0.7957]), 1),
#  (DenseVector([0.8857, 0.1241]), 1),
#  (DenseVector([0.7141, 0.7975]), 1),
#  (DenseVector([0.1178, 0.4495]), 1),
#  (DenseVector([0.5054, 0.0321]), 1),
#  (DenseVector([0.5955, 0.7684]), 1),
#  (DenseVector([0.6375, 0.3382]), 1),
#  (DenseVector([0.5251, 0.3737]), 1),
#  (DenseVector([0.8084, 0.4]), 1),
#  (DenseVector([0.548, 0.1807]), 1),
#  (DenseVector([0.4647, 0.4161]), 1),
#  (DenseVector([0.7509, 0.8639]), 1),
#  (DenseVector([0.2368, 0.5396]), 1),
#  (DenseVector([0.5398, 0.7388]), 1),
#  (DenseVector([0.6318, 0.577]), 1),
#  (DenseVector([0.0071, 0.5274]), 1),
#  (DenseVector([0.9592, 0.1423]), 1),
#  (DenseVector([0.1281, 0.8597]), 1),
#  (DenseVector([0.6854, 0.699]), 1),
#  (DenseVector([0.6096, 0.0073]), 1),
#  (DenseVector([0.7742, 0.2973]), 1),
#  (DenseVector([0.0341, 0.0458]), 1),
#  (DenseVector([0.7828, 0.0588]), 1),
#  (DenseVector([0.3379, 0.0414]), 1),
#  (DenseVector([0.1668, 0.6132]), 1),
#  (DenseVector([0.9278, 0.9793]), 1),
#  (DenseVector([0.1181, 0.9093]), 1),
#  (DenseVector([0.0969, 0.91]), 1),
#  (DenseVector([0.2638, 0.491]), 1),
#  (DenseVector([0.9148, 0.9997]), 1),
#  (DenseVector([0.6875, 0.5473]), 1),
#  (DenseVector([0.6544, 0.1096]), 1),
#  (DenseVector([0.5919, 0.5954]), 1),
#  (DenseVector([0.1209, 0.913]), 1),
#  (DenseVector([0.8384, 0.0075]), 1),
#  (DenseVector([0.241, 0.3663]), 1),
#  (DenseVector([0.5121, 0.0137]), 1),
#  (DenseVector([0.115, 0.9966]), 1),
#  (DenseVector([0.1002, 0.1225]), 1),
#  (DenseVector([0.4757, 0.7555]), 1),
#  (DenseVector([0.8401, 0.6839]), 1),
#  (DenseVector([0.2407, 0.2888]), 1),
#  (DenseVector([0.0744, 0.0917]), 1),
#  (DenseVector([0.0378, 0.4987]), 1),
#  (DenseVector([0.3768, 0.0337]), 1),
#  (DenseVector([0.6176, 0.2486]), 1),
#  (DenseVector([0.5556, 0.1341]), 1),
#  (DenseVector([0.5262, 0.022]), 1),
#  (DenseVector([0.932, 0.3095]), 1),
#  (DenseVector([0.6851, 0.1766]), 1),
#  (DenseVector([0.2327, 0.9996]), 1),
#  (DenseVector([0.4946, 0.2]), 1),
#  (DenseVector([0.5022, 0.2744]), 1),
#  (DenseVector([0.8071, 0.1404]), 1),
#  (DenseVector([0.2471, 0.9211]), 1),
#  (DenseVector([0.5879, 0.6437]), 1),
#  (DenseVector([0.5158, 0.8626]), 1),
#  (DenseVector([0.1941, 0.2066]), 1),
#  (DenseVector([0.524, 0.5137]), 1),
#  (DenseVector([0.7474, 0.2099]), 1),
#  (DenseVector([0.4317, 0.8917]), 1),
#  (DenseVector([0.9865, 0.7526]), 1),
#  (DenseVector([0.5057, 0.0289]), 1),
#  (DenseVector([0.8179, 0.6472]), 1),
#  (DenseVector([0.7796, 0.3338]), 1),
#  (DenseVector([0.1383, 0.0768]), 1),
#  (DenseVector([0.2292, 0.1038]), 1),
#  (DenseVector([0.1019, 0.2496]), 1),
#  (DenseVector([0.8606, 0.6545]), 1),
#  (DenseVector([0.1317, 0.2822]), 1),
#  (DenseVector([0.9148, 0.5336]), 1),
#  (DenseVector([0.1721, 0.0516]), 1),
#  (DenseVector([0.3542, 0.3362]), 1),
#  (DenseVector([0.712, 0.3584]), 1),
#  (DenseVector([0.1901, 0.9477]), 1),
#  (DenseVector([0.4217, 0.972]), 1),
#  (DenseVector([0.3951, 0.8776]), 1),
#  (DenseVector([0.0225, 0.5016]), 1),
#  (DenseVector([0.9873, 0.9701]), 1),
#  (DenseVector([0.2397, 0.3981]), 1),
#  (DenseVector([0.7634, 0.0071]), 1),
#  (DenseVector([0.2357, 0.6588]), 1),
#  (DenseVector([0.6491, 0.997]), 1),
#  (DenseVector([0.864, 0.1478]), 1),
#  (DenseVector([0.3467, 0.2931]), 1),
#  (DenseVector([0.5294, 0.2621]), 1),
#  (DenseVector([0.9373, 0.345]), 1),
#  (DenseVector([0.1516, 0.815]), 1),
#  (DenseVector([0.7052, 0.7946]), 1),
#  (DenseVector([0.076, 0.5186]), 1),
#  (DenseVector([0.6502, 0.7896]), 1),
#  (DenseVector([0.0926, 0.431]), 1),
#  (DenseVector([0.427, 0.4889]), 1),
#  (DenseVector([0.7431, 0.0501]), 1),
#  (DenseVector([0.7304, 0.7148]), 1),
#  (DenseVector([0.1842, 0.6288]), 1),
#  (DenseVector([0.6532, 0.9283]), 1),
#  (DenseVector([0.5949, 0.3606]), 1),
#  (DenseVector([0.0013, 0.6878]), 1),
#  (DenseVector([0.2685, 0.3816]), 1),
#  (DenseVector([0.6824, 0.0341]), 1),
#  (DenseVector([0.1079, 0.7677]), 1),
#  (DenseVector([0.0766, 0.9321]), 1),
#  (DenseVector([0.6964, 0.3126]), 1),
#  (DenseVector([0.6443, 0.4655]), 1),
#  (DenseVector([0.1057, 0.7535]), 1),
#  (DenseVector([0.0427, 0.9003]), 1),
#  (DenseVector([0.7348, 0.6822]), 1),
#  (DenseVector([0.1611, 0.1963]), 1),
#  (DenseVector([0.1552, 0.0198]), 1),
#  (DenseVector([0.6379, 0.0712]), 1),
#  (DenseVector([0.5529, 0.9026]), 1),
#  (DenseVector([0.5442, 0.6595]), 1),
#  (DenseVector([0.1877, 0.869]), 1),
#  (DenseVector([0.5568, 0.2384]), 1),
#  (DenseVector([0.9452, 0.0436]), 1),
#  (DenseVector([0.5061, 0.6317]), 1),
#  (DenseVector([0.7692, 0.7626]), 1),
#  (DenseVector([0.8074, 0.0283]), 1),
#  (DenseVector([0.8495, 0.511]), 1),
#  (DenseVector([0.4414, 0.4106]), 1),
#  (DenseVector([0.8334, 0.3871]), 1),
#  (DenseVector([0.2179, 0.9172]), 1),
#  (DenseVector([0.5651, 0.6476]), 1),
#  (DenseVector([0.856, 0.0498]), 1),
#  (DenseVector([0.8287, 0.2058]), 1),
#  (DenseVector([0.9158, 0.7632]), 1),
#  (DenseVector([0.2102, 0.3666]), 1),
#  (DenseVector([0.0839, 0.2987]), 1),
#  (DenseVector([0.2768, 0.7924]), 1),
#  (DenseVector([0.7653, 0.0809]), 1),
#  (DenseVector([0.256, 0.9761]), 1),
#  (DenseVector([0.9515, 0.5263]), 1),
#  (DenseVector([0.7442, 0.3478]), 1),
#  (DenseVector([0.7933, 0.4432]), 1),
#  (DenseVector([0.8817, 0.313]), 1),
#  (DenseVector([0.5885, 0.6506]), 1),
#  (DenseVector([0.8332, 0.4086]), 1),
#  (DenseVector([0.3462, 0.3721]), 1),
#  (DenseVector([0.9887, 0.4302]), 1),
#  (DenseVector([0.9854, 0.8575]), 1),
#  (DenseVector([0.2351, 0.653]), 1),
#  (DenseVector([0.1352, 0.4735]), 1),
#  (DenseVector([0.4007, 0.4117]), 1),
#  (DenseVector([0.2483, 0.5226]), 1),
#  (DenseVector([0.3545, 0.7548]), 1),
#  (DenseVector([0.8833, 0.209]), 1),
#  (DenseVector([0.7892, 0.9289]), 1),
#  (DenseVector([0.9115, 0.5921]), 1),
#  (DenseVector([0.5131, 0.8901]), 1),
#  (DenseVector([0.0306, 0.2671]), 1),
#  (DenseVector([0.8379, 0.8938]), 1),
#  (DenseVector([0.7421, 0.2528]), 1),
#  (DenseVector([0.4552, 0.2808]), 1),
#  (DenseVector([0.4941, 0.6294]), 1),
#  (DenseVector([0.5046, 0.1049]), 1),
#  (DenseVector([0.5614, 0.9553]), 1),
#  (DenseVector([0.4685, 0.2696]), 1),
#  (DenseVector([0.7058, 0.2331]), 1),
#  (DenseVector([0.3375, 0.9659]), 1),
#  (DenseVector([0.9959, 0.177]), 1),
#  (DenseVector([0.3501, 0.6191]), 1),
#  (DenseVector([0.2695, 0.8796]), 1),
#  (DenseVector([0.4745, 0.0295]), 1),
#  (DenseVector([0.3657, 0.9569]), 1),
#  (DenseVector([0.9749, 0.4368]), 1),
#  (DenseVector([0.9015, 0.1326]), 1),
#  (DenseVector([0.201, 0.3833]), 1),
#  (DenseVector([0.476, 0.8008]), 1),
#  (DenseVector([0.5147, 0.8741]), 1),
#  (DenseVector([0.2134, 0.728]), 1),
#  (DenseVector([0.5238, 0.364]), 1),
#  (DenseVector([0.3938, 0.1791]), 1),
#  (DenseVector([0.3885, 0.5834]), 1),
#  (DenseVector([0.8919, 0.8212]), 1),
#  (DenseVector([0.922, 0.7853]), 1),
#  (DenseVector([0.0539, 0.8305]), 1),
#  (DenseVector([0.2457, 0.6504]), 1),
#  (DenseVector([0.4841, 0.1646]), 1),
#  (DenseVector([0.6409, 0.3729]), 1),
#  (DenseVector([0.1256, 0.6255]), 1),
#  (DenseVector([0.7915, 0.7296]), 1),
#  (DenseVector([0.5155, 0.2474]), 1),
#  (DenseVector([0.056, 0.4966]), 1),
#  (DenseVector([0.0851, 0.9142]), 1),
#  (DenseVector([0.3525, 0.3623]), 1),
#  (DenseVector([0.1331, 0.1967]), 1),
#  (DenseVector([0.1425, 0.5975]), 1),
#  (DenseVector([0.114, 0.0179]), 1),
#  (DenseVector([0.6947, 0.1112]), 1),
#  (DenseVector([0.4266, 0.0618]), 1),
#  (DenseVector([0.0876, 0.0403]), 1),
#  (DenseVector([0.9014, 0.7495]), 1),
#  (DenseVector([0.4302, 0.0627]), 1),
#  (DenseVector([0.188, 0.5174]), 1),
#  (DenseVector([0.8928, 0.2693]), 1),
#  (DenseVector([0.815, 0.2639]), 1),
#  (DenseVector([0.0868, 0.5804]), 1),
#  (DenseVector([0.5957, 0.6809]), 1),
#  (DenseVector([0.9096, 0.864]), 1),
#  (DenseVector([0.1268, 0.826]), 1),
#  (DenseVector([0.0024, 0.0228]), 1),
#  (DenseVector([0.8006, 0.8854]), 1),
#  (DenseVector([0.0726, 0.6873]), 1),
#  (DenseVector([0.8122, 0.4483]), 1),
#  (DenseVector([0.265, 0.8559]), 1),
#  (DenseVector([0.2393, 0.321]), 1),
#  (DenseVector([0.0989, 0.3795]), 1),
#  (DenseVector([0.8591, 0.0561]), 1),
#  (DenseVector([0.032, 0.1415]), 1),
#  (DenseVector([0.6367, 0.6769]), 1),
#  (DenseVector([0.5973, 0.5356]), 1),
#  (DenseVector([0.5813, 0.6994]), 1),
#  (DenseVector([0.4025, 0.4073]), 1),
#  (DenseVector([0.1518, 0.5944]), 1),
#  (DenseVector([0.4913, 0.2897]), 1),
#  (DenseVector([0.9452, 0.5374]), 1),
#  (DenseVector([0.6669, 0.5627]), 1),
#  (DenseVector([0.9595, 0.2714]), 1),
#  (DenseVector([0.5039, 0.4798]), 1),
#  (DenseVector([0.3825, 0.8397]), 1),
#  (DenseVector([0.6117, 0.2978]), 1),
#  (DenseVector([0.4018, 0.5322]), 1),
#  (DenseVector([0.9116, 0.8807]), 1),
#  (DenseVector([0.2236, 0.933]), 1),
#  (DenseVector([0.0561, 0.0378]), 1),
#  (DenseVector([0.4057, 0.0076]), 1),
#  (DenseVector([0.3844, 0.9592]), 1),
#  (DenseVector([0.9063, 0.2525]), 1),
#  (DenseVector([0.2535, 0.6483]), 1),
#  (DenseVector([0.968, 0.8761]), 1),
#  (DenseVector([0.8398, 0.1699]), 1),
#  (DenseVector([0.1693, 0.7976]), 1),
#  (DenseVector([0.8742, 0.07]), 1),
#  (DenseVector([0.8903, 0.5805]), 1),
#  (DenseVector([0.735, 0.8067]), 1),
#  (DenseVector([0.7036, 0.745]), 1),
#  (DenseVector([0.999, 0.3067]), 1),
#  (DenseVector([0.7161, 0.9918]), 1),
#  (DenseVector([0.8413, 0.5589]), 1),
#  (DenseVector([0.5259, 0.5521]), 1),
#  (DenseVector([0.7478, 0.5315]), 1),
#  (DenseVector([0.0284, 0.8666]), 1),
#  (DenseVector([0.9789, 0.1741]), 1),
#  (DenseVector([0.3005, 0.9233]), 1),
#  (DenseVector([0.9115, 0.5562]), 1),
#  (DenseVector([0.3608, 0.9719]), 1),
#  (DenseVector([0.7301, 0.4186]), 1),
#  (DenseVector([0.4707, 0.9517]), 1),
#  (DenseVector([0.2167, 0.1374]), 1),
#  (DenseVector([0.1116, 0.9061]), 1),
#  (DenseVector([0.4919, 0.9093]), 1),
#  (DenseVector([0.6907, 0.6675]), 1),
#  (DenseVector([0.4346, 0.1973]), 1),
#  (DenseVector([0.9378, 0.6431]), 1),
#  (DenseVector([0.7353, 0.6575]), 1),
#  (DenseVector([0.0479, 0.0409]), 1),
#  (DenseVector([0.3607, 0.1549]), 1),
#  (DenseVector([0.5875, 0.9021]), 1),
#  (DenseVector([0.9348, 0.0999]), 1),
#  (DenseVector([0.279, 0.0335]), 1),
#  (DenseVector([0.8308, 0.3196]), 1),
#  (DenseVector([0.3581, 0.6255]), 1),
#  (DenseVector([0.6228, 0.1555]), 1),
#  (DenseVector([0.6163, 0.6309]), 1),
#  (DenseVector([0.245, 0.6439]), 1),
#  (DenseVector([0.819, 0.3828]), 1),
#  (DenseVector([0.0543, 0.1875]), 1),
#  (DenseVector([0.9615, 0.0831]), 1),
#  (DenseVector([0.5735, 0.5549]), 1),
#  (DenseVector([0.0196, 0.7841]), 1),
#  (DenseVector([0.5392, 0.62]), 1),
#  (DenseVector([0.6797, 0.4347]), 1),
#  (DenseVector([0.981, 0.815]), 1),
#  (DenseVector([0.3858, 0.6964]), 1),
#  (DenseVector([0.7334, 0.7984]), 1),
#  (DenseVector([0.9714, 0.7691]), 1),
#  (DenseVector([0.218, 0.9459]), 1),
#  (DenseVector([0.5526, 0.5836]), 1),
#  (DenseVector([0.1634, 0.7803]), 1),
#  (DenseVector([0.8982, 0.5037]), 1),
#  (DenseVector([0.2404, 0.7965]), 1),
#  (DenseVector([0.1263, 0.1269]), 1),
#  (DenseVector([0.9643, 0.9469]), 1),
#  (DenseVector([0.4502, 0.3553]), 1),
#  (DenseVector([0.3491, 0.4209]), 1),
#  (DenseVector([0.3414, 0.5232]), 1),
#  (DenseVector([0.0213, 0.0681]), 1),
#  (DenseVector([0.7987, 0.8538]), 1),
#  (DenseVector([0.4194, 0.3186]), 1),
#  (DenseVector([0.0063, 0.579]), 1),
#  (DenseVector([0.5691, 0.5836]), 1),
#  (DenseVector([0.2363, 0.4523]), 1),
#  (DenseVector([0.9372, 0.9294]), 1),
#  (DenseVector([0.0938, 0.7426]), 1),
#  (DenseVector([0.8014, 0.7362]), 1),
#  (DenseVector([0.6533, 0.9892]), 1),
#  (DenseVector([0.486, 0.4331]), 1),
#  (DenseVector([0.1266, 0.3852]), 1),
#  (DenseVector([0.619, 0.4129]), 1),
#  (DenseVector([0.0258, 0.0038]), 1),
#  (DenseVector([0.2079, 0.7715]), 1),
#  (DenseVector([0.8105, 0.5981]), 1),
#  (DenseVector([0.6818, 0.5373]), 1),
#  (DenseVector([0.2539, 0.8295]), 1),
#  (DenseVector([0.9872, 0.0004]), 1),
#  (DenseVector([0.7471, 0.6421]), 1),
#  (DenseVector([0.9638, 0.0594]), 1),
#  (DenseVector([0.6612, 0.1133]), 1),
#  (DenseVector([0.0559, 0.5601]), 1),
#  (DenseVector([0.8232, 0.4585]), 1),
#  (DenseVector([0.9411, 0.3747]), 1),
#  (DenseVector([0.9118, 0.5882]), 1),
#  (DenseVector([0.9933, 0.2609]), 1),
#  (DenseVector([0.0323, 0.0799]), 1),
#  (DenseVector([0.3496, 0.7889]), 1),
#  (DenseVector([0.121, 0.031]), 1),
#  (DenseVector([0.557, 0.8766]), 1),
#  (DenseVector([0.7317, 0.147]), 1),
#  (DenseVector([0.5206, 0.5703]), 1),
#  (DenseVector([0.8673, 0.1572]), 1),
#  (DenseVector([0.2276, 0.3661]), 1),
#  (DenseVector([0.2828, 0.1491]), 1),
#  (DenseVector([0.3997, 0.4891]), 1),
#  (DenseVector([0.4821, 0.858]), 1),
#  (DenseVector([0.9443, 0.2018]), 1),
#  (DenseVector([0.4978, 0.286]), 1),
#  (DenseVector([0.5706, 0.113]), 1),
#  (DenseVector([0.8623, 0.5254]), 1),
#  (DenseVector([0.2748, 0.0517]), 1),
#  (DenseVector([0.7509, 0.5143]), 1),
#  (DenseVector([0.3923, 0.4128]), 1),
#  (DenseVector([0.8984, 0.1524]), 1),
#  (DenseVector([0.6214, 0.4475]), 1),
#  (DenseVector([0.0936, 0.4798]), 1),
#  (DenseVector([0.4114, 0.467]), 1),
#  (DenseVector([0.1726, 0.5617]), 1),
#  (DenseVector([0.8641, 0.3529]), 1),
#  (DenseVector([0.5722, 0.2845]), 1),
#  (DenseVector([0.439, 0.647]), 1),
#  (DenseVector([0.0405, 0.0063]), 1),
#  (DenseVector([0.3379, 0.7344]), 1),
#  (DenseVector([0.1276, 0.2354]), 1),
#  (DenseVector([0.9419, 0.4391]), 1),
#  (DenseVector([0.4009, 0.1075]), 1),
#  (DenseVector([0.9627, 0.9296]), 1),
#  (DenseVector([0.936, 0.2201]), 1),
#  (DenseVector([0.181, 0.0889]), 1),
#  (DenseVector([0.301, 0.5037]), 1),
#  (DenseVector([0.5879, 0.3639]), 1),
#  (DenseVector([0.867, 0.3357]), 1),
#  (DenseVector([0.4953, 0.823]), 1),
#  (DenseVector([0.6631, 0.8161]), 1),
#  (DenseVector([0.8399, 0.0964]), 1),
#  (DenseVector([0.904, 0.4663]), 1),
#  (DenseVector([0.4868, 0.9273]), 1),
#  (DenseVector([0.4143, 0.4867]), 1),
#  (DenseVector([0.5185, 0.0246]), 1),
#  (DenseVector([0.3037, 0.0183]), 1),
#  (DenseVector([0.864, 0.3054]), 1),
#  (DenseVector([0.79, 0.6529]), 1),
#  (DenseVector([0.1199, 0.1335]), 1),
#  (DenseVector([0.8753, 0.6978]), 1),
#  (DenseVector([0.7409, 0.9127]), 1),
#  (DenseVector([0.639, 0.2271]), 1),
#  (DenseVector([0.2485, 0.4157]), 1),
#  (DenseVector([0.5358, 0.892]), 1),
#  (DenseVector([0.0137, 0.0862]), 1),
#  (DenseVector([0.5556, 0.2873]), 1),
#  (DenseVector([0.2181, 0.6207]), 1),
#  (DenseVector([0.1925, 0.1293]), 1),
#  (DenseVector([0.9985, 0.7607]), 1),
#  (DenseVector([0.8882, 0.7327]), 1),
#  (DenseVector([0.9415, 0.2745]), 1),
#  (DenseVector([0.8744, 0.898]), 1),
#  (DenseVector([0.7471, 0.6455]), 1),
#  (DenseVector([0.6225, 0.0343]), 1),
#  (DenseVector([0.0073, 0.9081]), 1),
#  (DenseVector([0.1886, 0.8825]), 1),
#  (DenseVector([0.7856, 0.3253]), 1),
#  (DenseVector([0.8158, 0.5631]), 1),
#  (DenseVector([0.5792, 0.0913]), 1),
#  (DenseVector([0.8288, 0.4436]), 1),
#  (DenseVector([0.0931, 0.7884]), 1),
#  (DenseVector([0.7441, 0.8026]), 1),
#  (DenseVector([0.1869, 0.5434]), 1),
#  (DenseVector([0.3578, 0.1287]), 1),
#  (DenseVector([0.8488, 0.0681]), 1),
#  (DenseVector([0.7528, 0.6992]), 1),
#  (DenseVector([0.5707, 0.4644]), 1),
#  (DenseVector([0.8305, 0.6805]), 1),
#  (DenseVector([0.5461, 0.6891]), 1),
#  (DenseVector([0.4989, 0.8368]), 1),
#  (DenseVector([0.204, 0.4595]), 1),
#  (DenseVector([0.9475, 0.5508]), 1),
#  (DenseVector([0.1693, 0.1807]), 1),
#  (DenseVector([0.9756, 0.4924]), 1),
#  (DenseVector([0.6181, 0.4363]), 1),
#  (DenseVector([0.2575, 0.6172]), 1),
#  (DenseVector([0.873, 0.3178]), 1),
#  (DenseVector([0.4178, 0.4229]), 1),
#  (DenseVector([0.3713, 0.3473]), 1),
#  (DenseVector([0.3419, 0.3095]), 1),
#  (DenseVector([0.8982, 0.3738]), 1),
#  (DenseVector([0.6674, 0.4375]), 1),
#  (DenseVector([0.8932, 0.5461]), 1),
#  (DenseVector([0.9491, 0.586]), 1),
#  (DenseVector([0.8242, 0.3302]), 1),
#  (DenseVector([0.3551, 0.8736]), 1),
#  (DenseVector([0.1379, 0.8196]), 1),
#  (DenseVector([0.1231, 0.6531]), 1),
#  (DenseVector([0.3212, 0.419]), 1),
#  (DenseVector([0.8851, 0.8675]), 1),
#  (DenseVector([0.3195, 0.2388]), 1),
#  (DenseVector([0.7436, 0.2161]), 1),
#  (DenseVector([0.4099, 0.3129]), 1),
#  (DenseVector([0.7797, 0.3411]), 1),
#  (DenseVector([0.3053, 0.5664]), 1),
#  (DenseVector([0.662, 0.9248]), 1),
#  (DenseVector([0.8943, 0.4753]), 1),
#  (DenseVector([0.6469, 0.947]), 1),
#  (DenseVector([0.6854, 0.3951]), 1),
#  (DenseVector([0.3943, 0.733]), 1),
#  (DenseVector([0.555, 0.0582]), 1),
#  (DenseVector([0.3402, 0.5136]), 1),
#  (DenseVector([0.8438, 0.6288]), 1),
#  (DenseVector([0.0137, 0.8136]), 1),
#  (DenseVector([0.7702, 0.517]), 1),
#  (DenseVector([0.9626, 0.1092]), 1),
#  (DenseVector([0.0847, 0.1576]), 1),
#  (DenseVector([0.5204, 0.9989]), 1),
#  (DenseVector([0.3882, 0.2616]), 1),
#  (DenseVector([0.0215, 0.0681]), 1),
#  (DenseVector([0.994, 0.1535]), 1),
#  (DenseVector([0.1814, 0.8959]), 1),
#  (DenseVector([0.1715, 0.5223]), 1),
#  (DenseVector([0.0285, 0.6552]), 1),
#  (DenseVector([0.4226, 0.2934]), 1),
#  (DenseVector([0.9671, 0.6266]), 1),
#  (DenseVector([0.7206, 0.5951]), 1),
#  (DenseVector([0.2366, 0.0253]), 1),
#  (DenseVector([0.055, 0.3435]), 1),
#  (DenseVector([0.4726, 0.1414]), 1),
#  (DenseVector([0.0667, 0.8481]), 1),
#  (DenseVector([0.0935, 0.6502]), 1),
#  (DenseVector([0.7307, 0.8919]), 1),
#  (DenseVector([0.7223, 0.5218]), 1),
#  (DenseVector([0.5497, 0.7178]), 1),
#  (DenseVector([0.5548, 0.877]), 1),
#  (DenseVector([0.1765, 0.48]), 1),
#  (DenseVector([0.5086, 0.891]), 1),
#  (DenseVector([0.4303, 0.3017]), 1),
#  (DenseVector([0.6087, 0.0508]), 1),
#  (DenseVector([0.6993, 0.6327]), 1),
#  (DenseVector([0.6639, 0.7088]), 1),
#  (DenseVector([0.6731, 0.9023]), 1),
#  (DenseVector([0.5149, 0.8807]), 1),
#  (DenseVector([0.3751, 0.9619]), 1),
#  (DenseVector([0.791, 0.4197]), 1),
#  (DenseVector([0.7566, 0.4419]), 1),
#  (DenseVector([0.4818, 0.7002]), 1),
#  (DenseVector([0.3708, 0.3527]), 1),
#  (DenseVector([0.4568, 0.6214]), 1),
#  (DenseVector([0.1467, 0.8082]), 1),
#  (DenseVector([0.1723, 0.2755]), 1),
#  (DenseVector([0.3616, 0.3193]), 1),
#  (DenseVector([0.3116, 0.559]), 1),
#  (DenseVector([0.8929, 0.5453]), 1),
#  (DenseVector([0.0279, 0.8862]), 1),
#  (DenseVector([0.482, 0.6094]), 1),
#  (DenseVector([0.922, 0.9805]), 1),
#  (DenseVector([0.0938, 0.2097]), 1),
#  (DenseVector([0.2497, 0.9819]), 1),
#  (DenseVector([0.1705, 0.3342]), 1),
#  (DenseVector([0.1872, 0.2981]), 1),
#  (DenseVector([0.7784, 0.1002]), 1),
#  (DenseVector([0.3164, 0.665]), 1),
#  (DenseVector([0.4179, 0.2512]), 1),
#  (DenseVector([0.5375, 0.5953]), 1),
#  (DenseVector([0.4034, 0.9585]), 1),
#  (DenseVector([0.8561, 0.5544]), 1),
#  (DenseVector([0.353, 0.6518]), 1),
#  (DenseVector([0.4751, 0.4795]), 1),
#  (DenseVector([0.5602, 0.4195]), 1),
#  (DenseVector([0.2535, 0.9241]), 1),
#  (DenseVector([0.2989, 0.1882]), 1),
#  (DenseVector([0.2445, 0.1187]), 1),
#  (DenseVector([0.0206, 0.582]), 1),
#  (DenseVector([0.5115, 0.4617]), 1),
#  (DenseVector([0.5326, 0.9367]), 1),
#  (DenseVector([0.4091, 0.6981]), 1),
#  (DenseVector([0.5818, 0.2566]), 1),
#  (DenseVector([0.1884, 0.4745]), 1),
#  (DenseVector([0.705, 0.1914]), 1),
#  (DenseVector([0.4346, 0.9814]), 1),
#  (DenseVector([0.3006, 0.9946]), 1),
#  (DenseVector([0.9875, 0.8319]), 1),
#  (DenseVector([0.383, 0.4694]), 1),
#  (DenseVector([0.7481, 0.0839]), 1),
#  (DenseVector([0.5763, 0.0566]), 1),
#  (DenseVector([0.538, 0.6901]), 1),
#  (DenseVector([0.9264, 0.0803]), 1),
#  (DenseVector([0.6468, 0.8919]), 1),
#  (DenseVector([0.0007, 0.212]), 1),
#  (DenseVector([0.8574, 0.2033]), 1),
#  (DenseVector([0.7894, 0.6309]), 1),
#  (DenseVector([0.8342, 0.0836]), 1),
#  (DenseVector([0.8124, 0.8108]), 1),
#  (DenseVector([0.0525, 0.3127]), 1),
#  (DenseVector([0.6163, 0.5479]), 1),
#  (DenseVector([0.8124, 0.6153]), 1),
#  (DenseVector([0.2238, 0.2011]), 1),
#  (DenseVector([0.6865, 0.8027]), 1),
#  (DenseVector([0.0004, 0.1914]), 1),
#  (DenseVector([0.4939, 0.2045]), 1),
#  (DenseVector([0.7135, 0.2416]), 1),
#  (DenseVector([0.8682, 0.8999]), 1),
#  (DenseVector([0.4238, 0.2547]), 1),
#  (DenseVector([0.5793, 0.4319]), 1),
#  (DenseVector([0.3647, 0.891]), 1),
#  (DenseVector([0.4129, 0.9646]), 1),
#  (DenseVector([0.5421, 0.2441]), 1),
#  (DenseVector([0.0985, 0.801]), 1),
#  (DenseVector([0.8365, 0.989]), 1),
#  (DenseVector([0.9001, 0.686]), 1),
#  (DenseVector([0.1262, 0.4445]), 1),
#  (DenseVector([0.3186, 0.6208]), 1),
#  (DenseVector([0.4753, 0.5189]), 1),
#  (DenseVector([0.9193, 0.1083]), 1),
#  (DenseVector([0.5199, 0.3912]), 1),
#  (DenseVector([0.6017, 0.5578]), 1),
#  (DenseVector([0.7076, 0.5849]), 1),
#  (DenseVector([0.9432, 0.6566]), 1),
#  (DenseVector([0.4943, 0.5812]), 1),
#  (DenseVector([0.8278, 0.0548]), 1),
#  (DenseVector([0.0378, 0.8384]), 1),
#  (DenseVector([0.776, 0.7756]), 1),
#  (DenseVector([0.4967, 0.785]), 1),
#  (DenseVector([0.048, 0.8917]), 1),
#  (DenseVector([0.2454, 0.7204]), 1),
#  (DenseVector([0.3795, 0.9518]), 1),
#  (DenseVector([0.593, 0.6967]), 1),
#  (DenseVector([0.58, 0.2185]), 1),
#  (DenseVector([0.5357, 0.7391]), 1),
#  (DenseVector([0.2464, 0.5719]), 1),
#  (DenseVector([0.2797, 0.1627]), 1),
#  (DenseVector([0.4602, 0.8655]), 1),
#  (DenseVector([0.9374, 0.0697]), 1),
#  (DenseVector([0.3922, 0.2425]), 1),
#  (DenseVector([0.9564, 0.7807]), 1),
#  (DenseVector([0.258, 0.2626]), 1),
#  (DenseVector([0.0511, 0.5281]), 1),
#  (DenseVector([0.7361, 0.9313]), 1),
#  (DenseVector([0.2656, 0.2273]), 1),
#  (DenseVector([0.7558, 0.4506]), 1),
#  (DenseVector([0.0278, 0.6733]), 1),
#  (DenseVector([0.2317, 0.691]), 1),
#  (DenseVector([0.958, 0.2348]), 1),
#  (DenseVector([0.4212, 0.1955]), 1),
#  (DenseVector([0.2517, 0.7914]), 1),
#  (DenseVector([0.9339, 0.5737]), 1),
#  (DenseVector([0.0995, 0.7424]), 1),
#  (DenseVector([0.3697, 0.384]), 1),
#  (DenseVector([0.7611, 0.9406]), 1),
#  (DenseVector([0.6914, 0.5462]), 1),
#  (DenseVector([0.1129, 0.9501]), 1),
#  (DenseVector([0.708, 0.7563]), 1),
#  (DenseVector([0.898, 0.4949]), 1),
#  (DenseVector([0.5612, 0.5445]), 1),
#  (DenseVector([0.004, 0.4299]), 1),
#  (DenseVector([0.4174, 0.3483]), 1),
#  (DenseVector([0.7626, 0.6945]), 1),
#  (DenseVector([0.2093, 0.1323]), 1),
#  (DenseVector([0.7625, 0.2416]), 1),
#  (DenseVector([0.1336, 0.6719]), 1),
#  (DenseVector([0.066, 0.1962]), 1),
#  (DenseVector([0.111, 0.074]), 1),
#  (DenseVector([0.3366, 0.2525]), 1),
#  (DenseVector([0.9393, 0.8558]), 1),
#  (DenseVector([0.184, 0.2071]), 1),
#  (DenseVector([0.316, 0.8324]), 1),
#  (DenseVector([0.5754, 0.7944]), 1),
#  (DenseVector([0.3216, 0.3143]), 1),
#  (DenseVector([0.7088, 0.2614]), 1),
#  (DenseVector([0.4029, 0.1472]), 1),
#  (DenseVector([0.8186, 0.8962]), 1),
#  (DenseVector([0.1131, 0.3089]), 1),
#  (DenseVector([0.6991, 0.5855]), 1),
#  (DenseVector([0.1691, 0.9839]), 1),
#  (DenseVector([0.0985, 0.2316]), 1),
#  (DenseVector([0.3878, 0.9064]), 1),
#  (DenseVector([0.5599, 0.823]), 1),
#  (DenseVector([0.6557, 0.5515]), 1),
#  (DenseVector([0.4271, 0.8228]), 1),
#  (DenseVector([0.5385, 0.8135]), 1),
#  (DenseVector([0.7402, 0.3028]), 1),
#  (DenseVector([0.5445, 0.0872]), 1),
#  (DenseVector([0.6581, 0.3037]), 1),
#  (DenseVector([0.2589, 0.8532]), 1),
#  (DenseVector([0.2711, 0.0957]), 1),
#  (DenseVector([0.6303, 0.3142]), 1),
#  (DenseVector([0.9386, 0.3297]), 1),
#  (DenseVector([0.0329, 0.3913]), 1),
#  (DenseVector([0.5067, 0.5775]), 1),
#  (DenseVector([0.8041, 0.5327]), 1),
#  (DenseVector([0.1008, 0.5288]), 1),
#  (DenseVector([0.3193, 0.7595]), 1),
#  (DenseVector([0.4741, 0.6601]), 1),
#  (DenseVector([0.2163, 0.0218]), 1),
#  (DenseVector([0.5606, 0.5684]), 1),
#  (DenseVector([0.6531, 0.8651]), 1),
#  (DenseVector([0.5134, 0.578]), 1),
#  (DenseVector([0.1061, 0.1352]), 1),
#  (DenseVector([0.3455, 0.5942]), 1),
#  (DenseVector([0.302, 0.9974]), 1),
#  (DenseVector([0.2308, 0.1026]), 1),
#  (DenseVector([0.137, 0.9722]), 1),
#  (DenseVector([0.7387, 0.853]), 1),
#  (DenseVector([0.8378, 0.0732]), 1),
#  (DenseVector([0.6807, 0.9329]), 1),
#  (DenseVector([0.3123, 0.1998]), 1),
#  (DenseVector([0.6035, 0.0357]), 1),
#  (DenseVector([0.5328, 0.7623]), 1),
#  (DenseVector([0.6405, 0.4781]), 1),
#  (DenseVector([0.2477, 0.6174]), 1),
#  (DenseVector([0.3876, 0.668]), 1),
#  (DenseVector([0.1077, 0.3792]), 1),
#  (DenseVector([0.7856, 0.1374]), 1),
#  (DenseVector([0.5737, 0.1291]), 1),
#  (DenseVector([0.0027, 0.8757]), 1),
#  (DenseVector([0.4528, 0.0177]), 1),
#  (DenseVector([0.2979, 0.4406]), 1),
#  (DenseVector([0.6439, 0.8072]), 1),
#  (DenseVector([0.3871, 0.685]), 1),
#  (DenseVector([0.788, 0.7817]), 1),
#  (DenseVector([0.2286, 0.7829]), 1),
#  (DenseVector([0.307, 0.3856]), 1),
#  (DenseVector([1.0, 0.1958]), 1),
#  (DenseVector([0.847, 0.7992]), 1),
#  (DenseVector([0.3086, 0.4177]), 1),
#  (DenseVector([0.0818, 0.5648]), 1),
#  (DenseVector([0.3527, 0.6243]), 1),
#  (DenseVector([0.5242, 0.2992]), 1),
#  (DenseVector([0.7828, 0.5575]), 1),
#  (DenseVector([0.0347, 0.6501]), 1),
#  (DenseVector([0.8666, 0.1104]), 1),
#  (DenseVector([0.5761, 0.5434]), 1),
#  (DenseVector([0.8895, 0.6323]), 1),
#  (DenseVector([0.0302, 0.7857]), 1),
#  (DenseVector([0.602, 0.3035]), 1),
#  (DenseVector([0.6524, 0.0861]), 1),
#  (DenseVector([0.9761, 0.0982]), 1),
#  (DenseVector([0.8714, 0.4744]), 1),
#  (DenseVector([0.9849, 0.2892]), 1),
#  (DenseVector([0.3217, 0.4194]), 1),
#  (DenseVector([0.5261, 0.7086]), 1),
#  (DenseVector([0.0178, 0.5196]), 1),
#  (DenseVector([0.7955, 0.2757]), 1),
#  (DenseVector([0.3928, 0.3511]), 1),
#  (DenseVector([0.8269, 0.5851]), 1),
#  (DenseVector([0.2134, 0.1654]), 1),
#  (DenseVector([0.9722, 0.8404]), 1),
#  (DenseVector([0.0899, 0.2411]), 1),
#  (DenseVector([0.7433, 0.6932]), 1),
#  (DenseVector([0.0009, 0.1038]), 1),
#  (DenseVector([0.9127, 0.7577]), 1),
#  (DenseVector([0.316, 0.2143]), 1),
#  (DenseVector([0.8728, 0.2971]), 1),
#  (DenseVector([0.4814, 0.0412]), 1),
#  (DenseVector([0.63, 0.3849]), 1),
#  (DenseVector([0.1999, 0.3544]), 1),
#  (DenseVector([0.9434, 0.6465]), 1),
#  (DenseVector([0.7601, 0.6205]), 1),
#  (DenseVector([0.3813, 0.0901]), 1),
#  (DenseVector([0.2861, 0.1968]), 1),
#  (DenseVector([0.7712, 0.7454]), 1),
#  (DenseVector([0.1323, 0.9936]), 1),
#  (DenseVector([0.8236, 0.813]), 1),
#  (DenseVector([0.1622, 0.0543]), 1),
#  (DenseVector([0.6361, 0.7144]), 1),
#  (DenseVector([0.9467, 0.5302]), 1),
#  (DenseVector([0.1698, 0.8661]), 1),
#  (DenseVector([0.505, 0.3192]), 1),
#  (DenseVector([0.3377, 0.0653]), 1),
#  (DenseVector([0.4226, 0.6296]), 1),
#  (DenseVector([0.9232, 0.7257]), 1),
#  (DenseVector([0.9493, 0.4169]), 1),
#  (DenseVector([0.9958, 0.0204]), 1),
#  (DenseVector([0.8358, 0.3095]), 1),
#  (DenseVector([0.2835, 0.147]), 1),
#  (DenseVector([0.717, 0.1925]), 1),
#  (DenseVector([0.8892, 0.0248]), 1),
#  (DenseVector([0.0851, 0.0196]), 1),
#  (DenseVector([0.244, 0.8347]), 1),
#  (DenseVector([0.0779, 0.6751]), 1),
#  (DenseVector([0.1805, 0.493]), 1),
#  (DenseVector([0.7243, 0.408]), 1),
#  (DenseVector([0.8007, 0.2656]), 1),
#  (DenseVector([0.1521, 0.8466]), 1),
#  (DenseVector([0.0182, 0.0046]), 1),
#  (DenseVector([0.0263, 0.825]), 1),
#  (DenseVector([0.6608, 0.5169]), 1),
#  (DenseVector([0.6438, 0.3137]), 1),
#  (DenseVector([0.2957, 0.4273]), 1),
#  (DenseVector([0.8773, 0.1018]), 1),
#  (DenseVector([0.6344, 0.2085]), 1),
#  (DenseVector([0.5917, 0.1493]), 1),
#  (DenseVector([0.5814, 0.5834]), 1),
#  (DenseVector([0.8304, 0.0561]), 1),
#  (DenseVector([0.1172, 0.3043]), 1),
#  (DenseVector([0.2035, 0.5896]), 1),
#  (DenseVector([0.6999, 0.7882]), 1),
#  (DenseVector([0.9582, 0.5346]), 1),
#  (DenseVector([0.9251, 0.9642]), 1),
#  (DenseVector([0.624, 0.1061]), 1),
#  (DenseVector([0.1249, 0.9316]), 1),
#  (DenseVector([0.1941, 0.5797]), 1),
#  (DenseVector([0.8221, 0.0858]), 1),
#  (DenseVector([0.9068, 0.5646]), 1),
#  (DenseVector([0.6748, 0.0121]), 1),
#  (DenseVector([0.3836, 0.6498]), 1),
#  (DenseVector([0.4326, 0.2758]), 1),
#  (DenseVector([0.5294, 0.7679]), 1),
#  (DenseVector([0.3566, 0.6047]), 1),
#  (DenseVector([0.9969, 0.5157]), 1),
#  (DenseVector([0.1272, 0.5945]), 1),
#  (DenseVector([0.0739, 0.5691]), 1),
#  (DenseVector([0.7682, 0.532]), 1),
#  (DenseVector([0.4053, 0.428]), 1),
#  (DenseVector([0.5576, 0.7483]), 1),
#  (DenseVector([0.0879, 0.5809]), 1),
#  (DenseVector([0.4719, 0.096]), 1),
#  (DenseVector([0.3666, 0.1136]), 1),
#  (DenseVector([0.545, 0.5722]), 1),
#  (DenseVector([0.479, 0.2555]), 1),
#  (DenseVector([0.6095, 0.8154]), 1),
#  (DenseVector([0.9334, 0.8192]), 1),
#  (DenseVector([0.0734, 0.7733]), 1),
#  (DenseVector([0.9178, 0.4806]), 1),
#  (DenseVector([0.8182, 0.1292]), 1),
#  (DenseVector([0.1478, 0.7396]), 1),
#  (DenseVector([0.1622, 0.2177]), 1),
#  (DenseVector([0.0868, 0.0448]), 1),
#  (DenseVector([0.6716, 0.469]), 1),
#  (DenseVector([0.9453, 0.5521]), 1),
#  (DenseVector([0.856, 0.437]), 1),
#  (DenseVector([0.4901, 0.2525]), 1),
#  (DenseVector([0.2746, 0.6949]), 1),
#  (DenseVector([0.3014, 0.401]), 1),
#  (DenseVector([0.8535, 0.6626]), 1),
#  (DenseVector([0.848, 0.8348]), 1),
#  (DenseVector([0.4322, 0.0712]), 1),
#  (DenseVector([0.1291, 0.1752]), 1),
#  (DenseVector([0.8409, 0.7111]), 1),
#  (DenseVector([0.7324, 0.856]), 1),
#  (DenseVector([0.1723, 0.244]), 1),
#  (DenseVector([0.4795, 0.9075]), 1),
#  (DenseVector([0.7069, 0.3585]), 1),
#  (DenseVector([0.7804, 0.7465]), 1),
#  (DenseVector([0.7431, 0.2428]), 1),
#  (DenseVector([0.9761, 0.8734]), 1),
#  (DenseVector([0.0776, 0.8759]), 1),
#  (DenseVector([0.1064, 0.0687]), 1),
#  (DenseVector([0.7643, 0.9542]), 1),
#  (DenseVector([0.8706, 0.6456]), 1),
#  (DenseVector([0.9253, 0.6725]), 1),
#  (DenseVector([0.4686, 0.9122]), 1),
#  (DenseVector([0.7357, 0.0367]), 1),
#  (DenseVector([0.8451, 0.9676]), 1),
#  (DenseVector([0.4323, 0.6761]), 1),
#  (DenseVector([0.1096, 0.3121]), 1),
#  (DenseVector([0.756, 0.0527]), 1),
#  (DenseVector([0.042, 0.1169]), 1),
#  (DenseVector([0.1314, 0.4219]), 1),
#  (DenseVector([0.823, 0.3965]), 1),
#  (DenseVector([0.3316, 0.8812]), 1),
#  (DenseVector([0.7744, 0.729]), 1),
#  (DenseVector([0.7123, 0.4914]), 1),
#  (DenseVector([0.9324, 0.1875]), 1),
#  (DenseVector([0.4946, 0.6294]), 1),
#  (DenseVector([0.5207, 0.4326]), 1),
#  (DenseVector([0.9553, 0.5923]), 1),
#  (DenseVector([0.4223, 0.6993]), 1),
#  (DenseVector([0.7238, 0.0682]), 1),
#  (DenseVector([0.1818, 0.582]), 1),
#  (DenseVector([0.5104, 0.1944]), 1),
#  (DenseVector([0.4595, 0.1016]), 1),
#  (DenseVector([0.9694, 0.305]), 1),
#  (DenseVector([0.8538, 0.4748]), 1),
#  (DenseVector([0.6955, 0.7641]), 1),
#  (DenseVector([0.9605, 0.63]), 1),
#  (DenseVector([0.0824, 0.4468]), 1),
#  (DenseVector([0.3894, 0.9986]), 1),
#  (DenseVector([0.3953, 0.848]), 1),
#  (DenseVector([0.3882, 0.6795]), 1),
#  (DenseVector([0.7708, 0.8632]), 1),
#  (DenseVector([0.6043, 0.7369]), 1),
#  (DenseVector([0.289, 0.1716]), 1),
#  (DenseVector([0.1535, 0.9272]), 1),
#  (DenseVector([0.3818, 0.6644]), 1),
#  (DenseVector([0.9337, 0.0843]), 1),
#  (DenseVector([0.19, 0.5327]), 1),
#  (DenseVector([0.0106, 0.622]), 1),
#  (DenseVector([0.66, 0.2819]), 1),
#  (DenseVector([0.9083, 0.5417]), 1),
#  (DenseVector([0.8386, 0.0185]), 1),
#  (DenseVector([0.9177, 0.7216]), 1),
#  (DenseVector([0.611, 0.9265]), 1),
#  (DenseVector([0.5767, 0.1135]), 1),
#  (DenseVector([0.5244, 0.022]), 1),
#  (DenseVector([0.1428, 0.335]), 1),
#  (DenseVector([0.8273, 0.7713]), 1),
#  (DenseVector([0.0199, 0.7887]), 1),
#  (DenseVector([0.1649, 0.7071]), 1),
#  (DenseVector([0.4867, 0.8354]), 1),
#  (DenseVector([0.1378, 0.5206]), 1),
#  (DenseVector([0.3619, 0.6658]), 1),
#  (DenseVector([0.0714, 0.2405]), 1),
#  (DenseVector([0.5318, 0.4558]), 1),
#  (DenseVector([0.5488, 0.9216]), 1),
#  (DenseVector([0.6069, 0.5052]), 1),
#  (DenseVector([0.8989, 0.8235]), 1),
#  (DenseVector([0.0035, 0.6532]), 1),
#  (DenseVector([0.9014, 0.7017]), 1),
#  (DenseVector([0.8715, 0.5674]), 1),
#  (DenseVector([0.506, 0.5033]), 1),
#  (DenseVector([0.145, 0.208]), 1),
#  (DenseVector([0.6215, 0.1996]), 1),
#  (DenseVector([0.3056, 0.7999]), 1),
#  (DenseVector([0.9204, 0.5209]), 1),
#  (DenseVector([0.6592, 0.2853]), 1),
#  (DenseVector([0.9458, 0.3252]), 1),
#  (DenseVector([0.1375, 0.9245]), 1),
#  (DenseVector([0.0934, 0.6831]), 1),
#  (DenseVector([0.1779, 0.1826]), 1),
#  (DenseVector([0.3505, 0.9548]), 1),
#  (DenseVector([0.1108, 0.5327]), 1),
#  (DenseVector([0.1431, 0.9939]), 1),
#  (DenseVector([0.8335, 0.8023]), 1),
#  (DenseVector([0.1949, 0.0863]), 1),
#  (DenseVector([0.0732, 0.0886]), 1),
#  (DenseVector([0.7194, 0.2973]), 1),
#  (DenseVector([0.273, 0.847]), 1),
#  (DenseVector([0.0821, 0.9073]), 1),
#  (DenseVector([0.2648, 0.0575]), 1),
#  (DenseVector([0.9331, 0.4606]), 1),
#  (DenseVector([0.5419, 0.0508]), 1),
#  (DenseVector([0.6284, 0.9414]), 1),
#  (DenseVector([0.4537, 0.4678]), 1),
#  (DenseVector([0.9327, 0.348]), 1),
#  (DenseVector([0.0142, 0.1861]), 1),
#  (DenseVector([0.3179, 0.9757]), 1),
#  (DenseVector([0.0022, 0.1686]), 1),
#  (DenseVector([0.5679, 0.3139]), 1),
#  (DenseVector([0.8353, 0.4903]), 1),
#  (DenseVector([0.0881, 0.9577]), 1),
#  (DenseVector([0.4551, 0.3791]), 1),
#  (DenseVector([0.6396, 0.9598]), 1),
#  (DenseVector([0.6427, 0.5331]), 1),
#  (DenseVector([0.4925, 0.9075]), 1),
#  (DenseVector([0.4055, 0.4346]), 1),
#  (DenseVector([0.395, 0.1104]), 1),
#  (DenseVector([0.9198, 0.3449]), 1),
#  (DenseVector([0.4219, 0.6813]), 1),
#  (DenseVector([0.282, 0.7452]), 1),
#  (DenseVector([0.8641, 0.8194]), 1),
#  (DenseVector([0.9928, 0.815]), 1),
#  (DenseVector([0.4293, 0.6508]), 1),
#  ...]

# %%
SKMeans(l, 2)
# Out:
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 21/12/25 20:23:50 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 21/12/25 20:23:58 WARN TaskSetManager: Stage 0 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:00 WARN TaskSetManager: Stage 1 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:00 WARN TaskSetManager: Stage 2 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:00 WARN TaskSetManager: Stage 3 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:01 WARN TaskSetManager: Stage 4 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:01 WARN TaskSetManager: Stage 5 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:01 WARN TaskSetManager: Stage 6 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:01 WARN TaskSetManager: Stage 8 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:02 WARN TaskSetManager: Stage 10 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:02 WARN TaskSetManager: Stage 12 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:02 WARN TaskSetManager: Stage 14 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:02 WARN TaskSetManager: Stage 16 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:02 WARN TaskSetManager: Stage 18 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:02 WARN TaskSetManager: Stage 20 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:02 WARN TaskSetManager: Stage 22 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:02 WARN TaskSetManager: Stage 24 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:02 WARN TaskSetManager: Stage 26 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:02 WARN TaskSetManager: Stage 28 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:02 WARN TaskSetManager: Stage 30 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:02 WARN TaskSetManager: Stage 32 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:03 WARN TaskSetManager: Stage 34 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:03 WARN TaskSetManager: Stage 36 contains a task of very large size (6455 KiB). The maximum recommended task size is 1000 KiB.
# 21/12/25 20:24:03 WARN TaskSetManager: Stage 38 contains a task of very large size (6454 KiB). The maximum recommended task size is 1000 KiB.
# [0.24822158 0.49976905]
# [0.74914753 0.50045147]
